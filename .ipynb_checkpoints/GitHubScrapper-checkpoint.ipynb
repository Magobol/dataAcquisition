# %%
import requests as r
from bs4 import BeautifulSoup
import re
import re
regex = re.compile(r'http.*|@.*')



github = 'https://gist.github.com/paulmillr/2657075'
def liste_refs(link):
      
    data = r.get(link).content
    soup = BeautifulSoup(data, 'html.parser')
    l=[]
    
#     for s in soup.find_all(class_='mw-parser-output')[0].select('a'):
#         a = s.get('href')
#         l.append(str(a))
    
#     regex = re.compile('\/wiki\w*')
#     tmp  = [s.getText().split(" ")[0] for s in soup.find_all('td')] 
    tmp = soup.find_all('td')
    
    u = []
    for s in tmp:
        try:u.append(s.find('a').getText())
        except:continue
        try:u.remove('')
        except: continue
            
    filtered = [i for i in u if not regex.match(i)]
    
    return filtered#list(filter(regex.search,l))

users = liste_refs(github)[:-3]
users
# Out:
# ['fabpot',
#  'andrew',
#  'taylorotwell',
#  'egoist',
#  'HugoGiraudel',
#  'ornicar',
#  'bebraw',
#  'nelsonic',
#  'alexcrichton',
#  'jonathanong',
#  'mikermcneil',
#  'benbalter',
#  'jxnblk',
#  'yegor256',
#  'orta',
#  'rstacruz',
#  'GrahamCampbell',
#  'afc163',
#  'kamranahmedse',
#  'joshaber',
#  'bkeepers',
#  'kennethreitz',
#  'kytrinyx',
#  'STRML',
#  'atmos',
#  'weierophinney',
#  'agentzh',
#  'steipete',
#  'ai',
#  'mikepenz',
#  'nvie',
#  'hadley',
#  'appleboy',
#  'Rich-Harris',
#  'drnic',
#  'rafaelfranca',
#  'Ocramius',
#  'mitchellh',
#  'stof',
#  'IgorMinar',
#  'phodal',
#  'jwiegley',
#  'geerlingguy',
#  'dcramer',
#  'sebastianbergmann',
#  'brunocvcunha',
#  'ljharb',
#  'jdalton',
#  'sevilayha',
#  'paulmillr',
#  'tmm1',
#  'c9s',
#  'zcbenz',
#  'holman',
#  'kevinsawicki',
#  'yihui',
#  'buckyroberts',
#  'kbrsh',
#  'dmalan',
#  'mhevery',
#  'mgechev',
#  'kylef',
#  'chjj',
#  'ayende',
#  'mcollina',
#  'mdo',
#  'yoshuawuyts',
#  'muan',
#  'kentcdodds',
#  'jskeet',
#  'mitsuhiko',
#  'steveklabnik',
#  'hzoo',
#  'Caged',
#  'dlew',
#  'technoweenie',
#  'gaearon',
#  'soumith',
#  'feross',
#  'michalbe',
#  'brianleroux',
#  'willdurand',
#  'alexjlockwood',
#  'matsko',
#  'stefanpenner',
#  'adamwathan',
#  'Haacked',
#  'curran',
#  'rauchg',
#  'ianstormtaylor',
#  'KrauseFx',
#  'tj',
#  'jgm',
#  'jverkoey',
#  'chenglou',
#  'DataTables',
#  'SamyPesse',
#  'mjhea0',
#  '0x00A',
#  'tmcw',
#  'brentvatne',
#  'carpedm20',
#  'benjamn',
#  'notwaldorf',
#  'miyagawa',
#  'rnystrom',
#  'photonstorm',
#  'mattn',
#  'dougwilson',
#  'JakeWharton',
#  'yyx990803',
#  'krzysztofzablocki',
#  'eduardolundgren',
#  'vjeux',
#  'mxcl',
#  'domenic',
#  'alex',
#  'mrdoob',
#  'josegonzalez',
#  'fzaninotto',
#  'pissang',
#  'jamesmontemagno',
#  'paulcbetts',
#  'paulirish',
#  'samdark',
#  'madskristensen',
#  'sokra',
#  'marijnh',
#  'alanhamlett',
#  'wesm',
#  'josevalim',
#  'jennybc',
#  'BurntSushi',
#  'zenorocha',
#  'contra',
#  'jaredhanson',
#  'radar',
#  'bevacqua',
#  'xudafeng',
#  'j2kun',
#  'dominictarr',
#  'avelino',
#  'vinta',
#  'developit',
#  'ashleygwilliams',
#  'ashfurrow',
#  'f',
#  'onevcat',
#  'toddmotto',
#  'gdi2290',
#  'EisenbergEffect',
#  'ankane',
#  'keijiro',
#  'nolimits4web',
#  'davidfowl',
#  'biezhi',
#  'LeaVerou',
#  'davidtmiller',
#  'odersky',
#  'vhf',
#  'soffes',
#  'mxstbr',
#  'Jinjiang',
#  'happypeter',
#  'yeasy',
#  'mafintosh',
#  'vczh',
#  'Draveness',
#  'ded',
#  'vladikoff',
#  'bnoordhuis',
#  'jendewalt',
#  'jessfraz',
#  'indutny',
#  'olivergierke',
#  'i5ting',
#  'laanwj',
#  'drakeet',
#  'thejameskyle',
#  'ahmetb',
#  'sdiehl',
#  'jaywcjlove',
#  'gitster',
#  'djspiewak',
#  'evilsocket',
#  'mariotaku',
#  'shama',
#  'CamDavidsonPilon',
#  'dsyer',
#  'winterbe',
#  'dennybritz',
#  'arun-gupta',
#  'maryrosecook',
#  'killme2008',
#  'IanLunn',
#  'ruanyf',
#  'binux',
#  'nfultz',
#  'leah',
#  'suissa',
#  'anishathalye',
#  'pkrumins',
#  'isaacs',
#  'staltz',
#  'KittenYang',
#  'leebyron',
#  'fengmk2',
#  'passy',
#  'gorhill',
#  'phuslu',
#  'mrmrs',
#  'siddontang',
#  'daylerees',
#  'weavejester',
#  'zce',
#  'philsturgeon',
#  'oldratlee',
#  'josephmisiti',
#  'atian25',
#  'ebidel',
#  'overtrue',
#  'connors',
#  'eliben',
#  'Seldaek',
#  'joyeecheung',
#  'bailicangdu',
#  'nikic',
#  'codahale',
#  'amitshekhariitbhu',
#  'rakyll',
#  'junyanz',
#  'simurai',
#  'nicolasgramlich',
#  'shiffman',
#  'purcell',
#  'evanphx',
#  'ericelliott',
#  'matyhtf',
#  'StephenGrider',
#  'AdamBien',
#  'rtomayko',
#  'tomchristie',
#  'be5invis',
#  'amueller',
#  'dead-horse',
#  'remy',
#  'Unknwon',
#  'jiyinyiyong',
#  'Shougo',
#  'arunoda',
#  'benoitc',
#  'ask',
#  'JohnSundell',
#  'Raynos',
#  'samuelclay',
#  'unicodeveloper']

# %%
import json
import pandas as pd
def connexion(user):
    api = r.get("https://api.github.com/users/{}/starred".format(user),headers={"Authorization":"15d2ae65a434e6375573c0c1f835c4d4d5008a2205329482273486611b4797ff"})
    return api

# connexion().json()[0]

def dataframeByUser():
   
    finaldf = pd.DataFrame()
    for u in users:
        l=[]
        try:
            for repo in connexion(u).json():
                l.append((repo['name'],repo['id'],repo['owner']['login'],repo['stargazers_count']))
#                 print(l)
                df = pd.DataFrame(l,columns=["name","id","owner","stars"])
#                 print(df.head(1))
                finaldf = finaldf.append(df)
        except:
            continue
    return finaldf

final = dataframeByUser()
final
# Out:
# [('var-exporter', 146569764, 'symfony', 1000)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664), ('cache', 41031609, 'php-fig', 3236)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664), ('cache', 41031609, 'php-fig', 3236), ('http-client', 174382335, 'symfony', 581)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664), ('cache', 41031609, 'php-fig', 3236), ('http-client', 174382335, 'symfony', 581), ('zend-eventmanager', 35280797, 'zendframework', 1578)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664), ('cache', 41031609, 'php-fig', 3236), ('http-client', 174382335, 'symfony', 581), ('zend-eventmanager', 35280797, 'zendframework', 1578), ('zend-code', 35617117, 'zendframework', 1630)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664), ('cache', 41031609, 'php-fig', 3236), ('http-client', 174382335, 'symfony', 581), ('zend-eventmanager', 35280797, 'zendframework', 1578), ('zend-code', 35617117, 'zendframework', 1630), ('assert', 32015820, 'webmozart', 6055)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664), ('cache', 41031609, 'php-fig', 3236), ('http-client', 174382335, 'symfony', 581), ('zend-eventmanager', 35280797, 'zendframework', 1578), ('zend-code', 35617117, 'zendframework', 1630), ('assert', 32015820, 'webmozart', 6055), ('webpack-encore-pack', 98284740, 'symfony', 498)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664), ('cache', 41031609, 'php-fig', 3236), ('http-client', 174382335, 'symfony', 581), ('zend-eventmanager', 35280797, 'zendframework', 1578), ('zend-code', 35617117, 'zendframework', 1630), ('assert', 32015820, 'webmozart', 6055), ('webpack-encore-pack', 98284740, 'symfony', 498), ('web-profiler-bundle', 2641412, 'symfony', 1471)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664), ('cache', 41031609, 'php-fig', 3236), ('http-client', 174382335, 'symfony', 581), ('zend-eventmanager', 35280797, 'zendframework', 1578), ('zend-code', 35617117, 'zendframework', 1630), ('assert', 32015820, 'webmozart', 6055), ('webpack-encore-pack', 98284740, 'symfony', 498), ('web-profiler-bundle', 2641412, 'symfony', 1471), ('web-link', 87835941, 'symfony', 807)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664), ('cache', 41031609, 'php-fig', 3236), ('http-client', 174382335, 'symfony', 581), ('zend-eventmanager', 35280797, 'zendframework', 1578), ('zend-code', 35617117, 'zendframework', 1630), ('assert', 32015820, 'webmozart', 6055), ('webpack-encore-pack', 98284740, 'symfony', 498), ('web-profiler-bundle', 2641412, 'symfony', 1471), ('web-link', 87835941, 'symfony', 807), ('var-dumper', 24498056, 'symfony', 5998)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664), ('cache', 41031609, 'php-fig', 3236), ('http-client', 174382335, 'symfony', 581), ('zend-eventmanager', 35280797, 'zendframework', 1578), ('zend-code', 35617117, 'zendframework', 1630), ('assert', 32015820, 'webmozart', 6055), ('webpack-encore-pack', 98284740, 'symfony', 498), ('web-profiler-bundle', 2641412, 'symfony', 1471), ('web-link', 87835941, 'symfony', 807), ('var-dumper', 24498056, 'symfony', 5998), ('validator', 1398672, 'symfony', 1756)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664), ('cache', 41031609, 'php-fig', 3236), ('http-client', 174382335, 'symfony', 581), ('zend-eventmanager', 35280797, 'zendframework', 1578), ('zend-code', 35617117, 'zendframework', 1630), ('assert', 32015820, 'webmozart', 6055), ('webpack-encore-pack', 98284740, 'symfony', 498), ('web-profiler-bundle', 2641412, 'symfony', 1471), ('web-link', 87835941, 'symfony', 807), ('var-dumper', 24498056, 'symfony', 5998), ('validator', 1398672, 'symfony', 1756), ('twig-bundle', 2641410, 'symfony', 1656)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664), ('cache', 41031609, 'php-fig', 3236), ('http-client', 174382335, 'symfony', 581), ('zend-eventmanager', 35280797, 'zendframework', 1578), ('zend-code', 35617117, 'zendframework', 1630), ('assert', 32015820, 'webmozart', 6055), ('webpack-encore-pack', 98284740, 'symfony', 498), ('web-profiler-bundle', 2641412, 'symfony', 1471), ('web-link', 87835941, 'symfony', 807), ('var-dumper', 24498056, 'symfony', 5998), ('validator', 1398672, 'symfony', 1756), ('twig-bundle', 2641410, 'symfony', 1656), ('translation', 1398671, 'symfony', 5580)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664), ('cache', 41031609, 'php-fig', 3236), ('http-client', 174382335, 'symfony', 581), ('zend-eventmanager', 35280797, 'zendframework', 1578), ('zend-code', 35617117, 'zendframework', 1630), ('assert', 32015820, 'webmozart', 6055), ('webpack-encore-pack', 98284740, 'symfony', 498), ('web-profiler-bundle', 2641412, 'symfony', 1471), ('web-link', 87835941, 'symfony', 807), ('var-dumper', 24498056, 'symfony', 5998), ('validator', 1398672, 'symfony', 1756), ('twig-bundle', 2641410, 'symfony', 1656), ('translation', 1398671, 'symfony', 5580), ('swiftmailer-bundle', 2641408, 'symfony', 1412)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664), ('cache', 41031609, 'php-fig', 3236), ('http-client', 174382335, 'symfony', 581), ('zend-eventmanager', 35280797, 'zendframework', 1578), ('zend-code', 35617117, 'zendframework', 1630), ('assert', 32015820, 'webmozart', 6055), ('webpack-encore-pack', 98284740, 'symfony', 498), ('web-profiler-bundle', 2641412, 'symfony', 1471), ('web-link', 87835941, 'symfony', 807), ('var-dumper', 24498056, 'symfony', 5998), ('validator', 1398672, 'symfony', 1756), ('twig-bundle', 2641410, 'symfony', 1656), ('translation', 1398671, 'symfony', 5580), ('swiftmailer-bundle', 2641408, 'symfony', 1412), ('stopwatch', 6631182, 'symfony', 1819)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664), ('cache', 41031609, 'php-fig', 3236), ('http-client', 174382335, 'symfony', 581), ('zend-eventmanager', 35280797, 'zendframework', 1578), ('zend-code', 35617117, 'zendframework', 1630), ('assert', 32015820, 'webmozart', 6055), ('webpack-encore-pack', 98284740, 'symfony', 498), ('web-profiler-bundle', 2641412, 'symfony', 1471), ('web-link', 87835941, 'symfony', 807), ('var-dumper', 24498056, 'symfony', 5998), ('validator', 1398672, 'symfony', 1756), ('twig-bundle', 2641410, 'symfony', 1656), ('translation', 1398671, 'symfony', 5580), ('swiftmailer-bundle', 2641408, 'symfony', 1412), ('stopwatch', 6631182, 'symfony', 1819), ('serializer-pack', 112522555, 'symfony', 882)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664), ('cache', 41031609, 'php-fig', 3236), ('http-client', 174382335, 'symfony', 581), ('zend-eventmanager', 35280797, 'zendframework', 1578), ('zend-code', 35617117, 'zendframework', 1630), ('assert', 32015820, 'webmozart', 6055), ('webpack-encore-pack', 98284740, 'symfony', 498), ('web-profiler-bundle', 2641412, 'symfony', 1471), ('web-link', 87835941, 'symfony', 807), ('var-dumper', 24498056, 'symfony', 5998), ('validator', 1398672, 'symfony', 1756), ('twig-bundle', 2641410, 'symfony', 1656), ('translation', 1398671, 'symfony', 5580), ('swiftmailer-bundle', 2641408, 'symfony', 1412), ('stopwatch', 6631182, 'symfony', 1819), ('serializer-pack', 112522555, 'symfony', 882), ('serializer', 1398663, 'symfony', 1524)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664), ('cache', 41031609, 'php-fig', 3236), ('http-client', 174382335, 'symfony', 581), ('zend-eventmanager', 35280797, 'zendframework', 1578), ('zend-code', 35617117, 'zendframework', 1630), ('assert', 32015820, 'webmozart', 6055), ('webpack-encore-pack', 98284740, 'symfony', 498), ('web-profiler-bundle', 2641412, 'symfony', 1471), ('web-link', 87835941, 'symfony', 807), ('var-dumper', 24498056, 'symfony', 5998), ('validator', 1398672, 'symfony', 1756), ('twig-bundle', 2641410, 'symfony', 1656), ('translation', 1398671, 'symfony', 5580), ('swiftmailer-bundle', 2641408, 'symfony', 1412), ('stopwatch', 6631182, 'symfony', 1819), ('serializer-pack', 112522555, 'symfony', 882), ('serializer', 1398663, 'symfony', 1524), ('security-bundle', 2641405, 'symfony', 1576)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664), ('cache', 41031609, 'php-fig', 3236), ('http-client', 174382335, 'symfony', 581), ('zend-eventmanager', 35280797, 'zendframework', 1578), ('zend-code', 35617117, 'zendframework', 1630), ('assert', 32015820, 'webmozart', 6055), ('webpack-encore-pack', 98284740, 'symfony', 498), ('web-profiler-bundle', 2641412, 'symfony', 1471), ('web-link', 87835941, 'symfony', 807), ('var-dumper', 24498056, 'symfony', 5998), ('validator', 1398672, 'symfony', 1756), ('twig-bundle', 2641410, 'symfony', 1656), ('translation', 1398671, 'symfony', 5580), ('swiftmailer-bundle', 2641408, 'symfony', 1412), ('stopwatch', 6631182, 'symfony', 1819), ('serializer-pack', 112522555, 'symfony', 882), ('serializer', 1398663, 'symfony', 1524), ('security-bundle', 2641405, 'symfony', 1576), ('security', 1398662, 'symfony', 1165)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('var-exporter', 146569764, 'symfony', 1000), ('service-contracts', 188791042, 'symfony', 891), ('polyfill-php73', 131031925, 'symfony', 1025), ('polyfill-intl-idn', 151089715, 'symfony', 1666), ('mime', 166176986, 'symfony', 1074), ('event-dispatcher-contracts', 188787832, 'symfony', 1215), ('error-renderer', 194141419, 'symfony', 59), ('error-handler', 197547987, 'symfony', 178), ('cache-contracts', 188785451, 'symfony', 645), ('log', 6936773, 'php-fig', 8145), ('container', 65755556, 'php-fig', 7664), ('cache', 41031609, 'php-fig', 3236), ('http-client', 174382335, 'symfony', 581), ('zend-eventmanager', 35280797, 'zendframework', 1578), ('zend-code', 35617117, 'zendframework', 1630), ('assert', 32015820, 'webmozart', 6055), ('webpack-encore-pack', 98284740, 'symfony', 498), ('web-profiler-bundle', 2641412, 'symfony', 1471), ('web-link', 87835941, 'symfony', 807), ('var-dumper', 24498056, 'symfony', 5998), ('validator', 1398672, 'symfony', 1756), ('twig-bundle', 2641410, 'symfony', 1656), ('translation', 1398671, 'symfony', 5580), ('swiftmailer-bundle', 2641408, 'symfony', 1412), ('stopwatch', 6631182, 'symfony', 1819), ('serializer-pack', 112522555, 'symfony', 882), ('serializer', 1398663, 'symfony', 1524), ('security-bundle', 2641405, 'symfony', 1576), ('security', 1398662, 'symfony', 1165), ('property-info', 43197094, 'symfony', 1193)]
#            name         id    owner  stars
# 0  var-exporter  146569764  symfony   1000
# [('babosa', 745521, 'norman', 406)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7), ('cargo-prefetch', 182166759, 'ehuss', 17)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7), ('cargo-prefetch', 182166759, 'ehuss', 17), ('cargo-cacher', 71492767, 'ChrisMacNaughton', 68)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7), ('cargo-prefetch', 182166759, 'ehuss', 17), ('cargo-cacher', 71492767, 'ChrisMacNaughton', 68), ('ims', 143657560, 'mafintosh', 188)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7), ('cargo-prefetch', 182166759, 'ehuss', 17), ('cargo-cacher', 71492767, 'ChrisMacNaughton', 68), ('ims', 143657560, 'mafintosh', 188), ('village-tracker', 189443494, 'ssbc', 12)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7), ('cargo-prefetch', 182166759, 'ehuss', 17), ('cargo-cacher', 71492767, 'ChrisMacNaughton', 68), ('ims', 143657560, 'mafintosh', 188), ('village-tracker', 189443494, 'ssbc', 12), ('semantic', 175839913, 'github', 6762)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7), ('cargo-prefetch', 182166759, 'ehuss', 17), ('cargo-cacher', 71492767, 'ChrisMacNaughton', 68), ('ims', 143657560, 'mafintosh', 188), ('village-tracker', 189443494, 'ssbc', 12), ('semantic', 175839913, 'github', 6762), ('peru', 13880738, 'buildinspace', 853)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7), ('cargo-prefetch', 182166759, 'ehuss', 17), ('cargo-cacher', 71492767, 'ChrisMacNaughton', 68), ('ims', 143657560, 'mafintosh', 188), ('village-tracker', 189443494, 'ssbc', 12), ('semantic', 175839913, 'github', 6762), ('peru', 13880738, 'buildinspace', 853), ('activity', 118674872, 'go-fed', 257)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7), ('cargo-prefetch', 182166759, 'ehuss', 17), ('cargo-cacher', 71492767, 'ChrisMacNaughton', 68), ('ims', 143657560, 'mafintosh', 188), ('village-tracker', 189443494, 'ssbc', 12), ('semantic', 175839913, 'github', 6762), ('peru', 13880738, 'buildinspace', 853), ('activity', 118674872, 'go-fed', 257), ('ipfs-npm-republish', 188057997, 'andrew', 7)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7), ('cargo-prefetch', 182166759, 'ehuss', 17), ('cargo-cacher', 71492767, 'ChrisMacNaughton', 68), ('ims', 143657560, 'mafintosh', 188), ('village-tracker', 189443494, 'ssbc', 12), ('semantic', 175839913, 'github', 6762), ('peru', 13880738, 'buildinspace', 853), ('activity', 118674872, 'go-fed', 257), ('ipfs-npm-republish', 188057997, 'andrew', 7), ('packrat', 13426098, 'rstudio', 321)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7), ('cargo-prefetch', 182166759, 'ehuss', 17), ('cargo-cacher', 71492767, 'ChrisMacNaughton', 68), ('ims', 143657560, 'mafintosh', 188), ('village-tracker', 189443494, 'ssbc', 12), ('semantic', 175839913, 'github', 6762), ('peru', 13880738, 'buildinspace', 853), ('activity', 118674872, 'go-fed', 257), ('ipfs-npm-republish', 188057997, 'andrew', 7), ('packrat', 13426098, 'rstudio', 321), ('paper-club', 186883372, 'package-community', 9)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7), ('cargo-prefetch', 182166759, 'ehuss', 17), ('cargo-cacher', 71492767, 'ChrisMacNaughton', 68), ('ims', 143657560, 'mafintosh', 188), ('village-tracker', 189443494, 'ssbc', 12), ('semantic', 175839913, 'github', 6762), ('peru', 13880738, 'buildinspace', 853), ('activity', 118674872, 'go-fed', 257), ('ipfs-npm-republish', 188057997, 'andrew', 7), ('packrat', 13426098, 'rstudio', 321), ('paper-club', 186883372, 'package-community', 9), ('esy', 107100376, 'esy', 561)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7), ('cargo-prefetch', 182166759, 'ehuss', 17), ('cargo-cacher', 71492767, 'ChrisMacNaughton', 68), ('ims', 143657560, 'mafintosh', 188), ('village-tracker', 189443494, 'ssbc', 12), ('semantic', 175839913, 'github', 6762), ('peru', 13880738, 'buildinspace', 853), ('activity', 118674872, 'go-fed', 257), ('ipfs-npm-republish', 188057997, 'andrew', 7), ('packrat', 13426098, 'rstudio', 321), ('paper-club', 186883372, 'package-community', 9), ('esy', 107100376, 'esy', 561), ('datasette', 107914493, 'simonw', 3000)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7), ('cargo-prefetch', 182166759, 'ehuss', 17), ('cargo-cacher', 71492767, 'ChrisMacNaughton', 68), ('ims', 143657560, 'mafintosh', 188), ('village-tracker', 189443494, 'ssbc', 12), ('semantic', 175839913, 'github', 6762), ('peru', 13880738, 'buildinspace', 853), ('activity', 118674872, 'go-fed', 257), ('ipfs-npm-republish', 188057997, 'andrew', 7), ('packrat', 13426098, 'rstudio', 321), ('paper-club', 186883372, 'package-community', 9), ('esy', 107100376, 'esy', 561), ('datasette', 107914493, 'simonw', 3000), ('webpackage', 71413286, 'WICG', 791)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7), ('cargo-prefetch', 182166759, 'ehuss', 17), ('cargo-cacher', 71492767, 'ChrisMacNaughton', 68), ('ims', 143657560, 'mafintosh', 188), ('village-tracker', 189443494, 'ssbc', 12), ('semantic', 175839913, 'github', 6762), ('peru', 13880738, 'buildinspace', 853), ('activity', 118674872, 'go-fed', 257), ('ipfs-npm-republish', 188057997, 'andrew', 7), ('packrat', 13426098, 'rstudio', 321), ('paper-club', 186883372, 'package-community', 9), ('esy', 107100376, 'esy', 561), ('datasette', 107914493, 'simonw', 3000), ('webpackage', 71413286, 'WICG', 791), ('timeless', 96472792, 'polydawn', 24)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7), ('cargo-prefetch', 182166759, 'ehuss', 17), ('cargo-cacher', 71492767, 'ChrisMacNaughton', 68), ('ims', 143657560, 'mafintosh', 188), ('village-tracker', 189443494, 'ssbc', 12), ('semantic', 175839913, 'github', 6762), ('peru', 13880738, 'buildinspace', 853), ('activity', 118674872, 'go-fed', 257), ('ipfs-npm-republish', 188057997, 'andrew', 7), ('packrat', 13426098, 'rstudio', 321), ('paper-club', 186883372, 'package-community', 9), ('esy', 107100376, 'esy', 561), ('datasette', 107914493, 'simonw', 3000), ('webpackage', 71413286, 'WICG', 791), ('timeless', 96472792, 'polydawn', 24), ('feedi', 176543861, 'davidesantangelo', 262)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7), ('cargo-prefetch', 182166759, 'ehuss', 17), ('cargo-cacher', 71492767, 'ChrisMacNaughton', 68), ('ims', 143657560, 'mafintosh', 188), ('village-tracker', 189443494, 'ssbc', 12), ('semantic', 175839913, 'github', 6762), ('peru', 13880738, 'buildinspace', 853), ('activity', 118674872, 'go-fed', 257), ('ipfs-npm-republish', 188057997, 'andrew', 7), ('packrat', 13426098, 'rstudio', 321), ('paper-club', 186883372, 'package-community', 9), ('esy', 107100376, 'esy', 561), ('datasette', 107914493, 'simonw', 3000), ('webpackage', 71413286, 'WICG', 791), ('timeless', 96472792, 'polydawn', 24), ('feedi', 176543861, 'davidesantangelo', 262), ('ruby-ext-wasm', 181576888, 'wasmerio', 198)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7), ('cargo-prefetch', 182166759, 'ehuss', 17), ('cargo-cacher', 71492767, 'ChrisMacNaughton', 68), ('ims', 143657560, 'mafintosh', 188), ('village-tracker', 189443494, 'ssbc', 12), ('semantic', 175839913, 'github', 6762), ('peru', 13880738, 'buildinspace', 853), ('activity', 118674872, 'go-fed', 257), ('ipfs-npm-republish', 188057997, 'andrew', 7), ('packrat', 13426098, 'rstudio', 321), ('paper-club', 186883372, 'package-community', 9), ('esy', 107100376, 'esy', 561), ('datasette', 107914493, 'simonw', 3000), ('webpackage', 71413286, 'WICG', 791), ('timeless', 96472792, 'polydawn', 24), ('feedi', 176543861, 'davidesantangelo', 262), ('ruby-ext-wasm', 181576888, 'wasmerio', 198), ('rutie', 137946784, 'danielpclark', 308)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7), ('cargo-prefetch', 182166759, 'ehuss', 17), ('cargo-cacher', 71492767, 'ChrisMacNaughton', 68), ('ims', 143657560, 'mafintosh', 188), ('village-tracker', 189443494, 'ssbc', 12), ('semantic', 175839913, 'github', 6762), ('peru', 13880738, 'buildinspace', 853), ('activity', 118674872, 'go-fed', 257), ('ipfs-npm-republish', 188057997, 'andrew', 7), ('packrat', 13426098, 'rstudio', 321), ('paper-club', 186883372, 'package-community', 9), ('esy', 107100376, 'esy', 561), ('datasette', 107914493, 'simonw', 3000), ('webpackage', 71413286, 'WICG', 791), ('timeless', 96472792, 'polydawn', 24), ('feedi', 176543861, 'davidesantangelo', 262), ('ruby-ext-wasm', 181576888, 'wasmerio', 198), ('rutie', 137946784, 'danielpclark', 308), ('gel', 112933756, 'gel-rb', 540)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('babosa', 745521, 'norman', 406), ('wikipedia-client', 556662, 'kenpratt', 248), ('itunes-podcasts', 18145185, 'driki', 10), ('vulnerablecode', 91780998, 'nexB', 35), ('repology-updater', 68022568, 'repology', 307), ('scarf', 172299326, 'aviaviavi', 83), ('diff2html', 23483401, 'rtfpessoa', 1087), ('gocenter', 159933264, 'jfrog', 128), ('ipfs-cluster', 62413100, 'ipfs', 619), ('sandman2', 25699392, 'jeffknupp', 1422), ('apt-on-ipfs', 176995796, 'ipfs-shipyard', 7), ('cargo-prefetch', 182166759, 'ehuss', 17), ('cargo-cacher', 71492767, 'ChrisMacNaughton', 68), ('ims', 143657560, 'mafintosh', 188), ('village-tracker', 189443494, 'ssbc', 12), ('semantic', 175839913, 'github', 6762), ('peru', 13880738, 'buildinspace', 853), ('activity', 118674872, 'go-fed', 257), ('ipfs-npm-republish', 188057997, 'andrew', 7), ('packrat', 13426098, 'rstudio', 321), ('paper-club', 186883372, 'package-community', 9), ('esy', 107100376, 'esy', 561), ('datasette', 107914493, 'simonw', 3000), ('webpackage', 71413286, 'WICG', 791), ('timeless', 96472792, 'polydawn', 24), ('feedi', 176543861, 'davidesantangelo', 262), ('ruby-ext-wasm', 181576888, 'wasmerio', 198), ('rutie', 137946784, 'danielpclark', 308), ('gel', 112933756, 'gel-rb', 540), ('manylinux', 49401134, 'pypa', 534)]
#      name      id   owner  stars
# 0  babosa  745521  norman    406
# [('math', 7551131, 'moontoast', 219)]
#    name       id      owner  stars
# 0  math  7551131  moontoast    219
# [('math', 7551131, 'moontoast', 219), ('laravel-postmark', 80351847, 'craigpaul', 103)]
#    name       id      owner  stars
# 0  math  7551131  moontoast    219
# [('math', 7551131, 'moontoast', 219), ('laravel-postmark', 80351847, 'craigpaul', 103), ('log-fake', 151792408, 'timacdonald', 204)]
#    name       id      owner  stars
# 0  math  7551131  moontoast    219
# [('math', 7551131, 'moontoast', 219), ('laravel-postmark', 80351847, 'craigpaul', 103), ('log-fake', 151792408, 'timacdonald', 204), ('advanced-eloquent', 158731830, 'reinink', 466)]
#    name       id      owner  stars
# 0  math  7551131  moontoast    219
# [('math', 7551131, 'moontoast', 219), ('laravel-postmark', 80351847, 'craigpaul', 103), ('log-fake', 151792408, 'timacdonald', 204), ('advanced-eloquent', 158731830, 'reinink', 466), ('form-backend-validation', 77405165, 'spatie', 710)]
#    name       id      owner  stars
# 0  math  7551131  moontoast    219
# [('math', 7551131, 'moontoast', 219), ('laravel-postmark', 80351847, 'craigpaul', 103), ('log-fake', 151792408, 'timacdonald', 204), ('advanced-eloquent', 158731830, 'reinink', 466), ('form-backend-validation', 77405165, 'spatie', 710), ('phpseclib', 4565995, 'phpseclib', 3623)]
#    name       id      owner  stars
# 0  math  7551131  moontoast    219
# [('math', 7551131, 'moontoast', 219), ('laravel-postmark', 80351847, 'craigpaul', 103), ('log-fake', 151792408, 'timacdonald', 204), ('advanced-eloquent', 158731830, 'reinink', 466), ('form-backend-validation', 77405165, 'spatie', 710), ('phpseclib', 4565995, 'phpseclib', 3623), ('once', 73020509, 'spatie', 596)]
#    name       id      owner  stars
# 0  math  7551131  moontoast    219
# ...
#       name        id    owner  stars
# 0  angular  24195339  angular  54825
# [('angular', 24195339, 'angular', 54825), ('angular-dart-phonecat', 16302747, 'technohippy', 19), ('traceur-compiler', 9060347, 'google', 8034), ('testacular', 4409224, 'mhevery', 4), ('karma', 2560988, 'karma-runner', 11012), ('ng-slides', 2038280, 'mhevery', 7), ('ng-slides', 2038274, 'IgorMinar', 19), ('angular-node-socketio', 1976165, 'mhevery', 123), ('everyjs.com', 1851714, 'mhevery', 6), ('todomvc', 1844251, 'tastejs', 26031), ('everyjs.com', 1819298, 'tomdale', 117), ('TestabilityBank', 1690044, 'mhevery', 3), ('TddCalculatorJava', 1688357, 'mhevery', 8), ('angular-demo-slides', 1413193, 'mhevery', 9), ('script.js', 1387097, 'ded', 2770), ('StoryNavigator', 1379292, 'paul-hammant', 25), ('angularjs.org', 1343653, 'angular', 265), ('angular-phonecat', 1170194, 'mhevery', 20), ('angular-phonecat', 1170151, 'IgorMinar', 4), ('mustache.js', 1036397, 'mhevery', 8), ('mustache', 1036381, 'mhevery', 2)]
#       name        id    owner  stars
# 0  angular  24195339  angular  54825
# [('angular', 24195339, 'angular', 54825), ('angular-dart-phonecat', 16302747, 'technohippy', 19), ('traceur-compiler', 9060347, 'google', 8034), ('testacular', 4409224, 'mhevery', 4), ('karma', 2560988, 'karma-runner', 11012), ('ng-slides', 2038280, 'mhevery', 7), ('ng-slides', 2038274, 'IgorMinar', 19), ('angular-node-socketio', 1976165, 'mhevery', 123), ('everyjs.com', 1851714, 'mhevery', 6), ('todomvc', 1844251, 'tastejs', 26031), ('everyjs.com', 1819298, 'tomdale', 117), ('TestabilityBank', 1690044, 'mhevery', 3), ('TddCalculatorJava', 1688357, 'mhevery', 8), ('angular-demo-slides', 1413193, 'mhevery', 9), ('script.js', 1387097, 'ded', 2770), ('StoryNavigator', 1379292, 'paul-hammant', 25), ('angularjs.org', 1343653, 'angular', 265), ('angular-phonecat', 1170194, 'mhevery', 20), ('angular-phonecat', 1170151, 'IgorMinar', 4), ('mustache.js', 1036397, 'mhevery', 8), ('mustache', 1036381, 'mhevery', 2), ('UglifyJS', 839076, 'mishoo', 8150)]
#       name        id    owner  stars
# 0  angular  24195339  angular  54825
# [('angular', 24195339, 'angular', 54825), ('angular-dart-phonecat', 16302747, 'technohippy', 19), ('traceur-compiler', 9060347, 'google', 8034), ('testacular', 4409224, 'mhevery', 4), ('karma', 2560988, 'karma-runner', 11012), ('ng-slides', 2038280, 'mhevery', 7), ('ng-slides', 2038274, 'IgorMinar', 19), ('angular-node-socketio', 1976165, 'mhevery', 123), ('everyjs.com', 1851714, 'mhevery', 6), ('todomvc', 1844251, 'tastejs', 26031), ('everyjs.com', 1819298, 'tomdale', 117), ('TestabilityBank', 1690044, 'mhevery', 3), ('TddCalculatorJava', 1688357, 'mhevery', 8), ('angular-demo-slides', 1413193, 'mhevery', 9), ('script.js', 1387097, 'ded', 2770), ('StoryNavigator', 1379292, 'paul-hammant', 25), ('angularjs.org', 1343653, 'angular', 265), ('angular-phonecat', 1170194, 'mhevery', 20), ('angular-phonecat', 1170151, 'IgorMinar', 4), ('mustache.js', 1036397, 'mhevery', 8), ('mustache', 1036381, 'mhevery', 2), ('UglifyJS', 839076, 'mishoo', 8150), ('ometa-js', 644874, 'alexwarth', 332)]
#       name        id    owner  stars
# 0  angular  24195339  angular  54825
# [('angular', 24195339, 'angular', 54825), ('angular-dart-phonecat', 16302747, 'technohippy', 19), ('traceur-compiler', 9060347, 'google', 8034), ('testacular', 4409224, 'mhevery', 4), ('karma', 2560988, 'karma-runner', 11012), ('ng-slides', 2038280, 'mhevery', 7), ('ng-slides', 2038274, 'IgorMinar', 19), ('angular-node-socketio', 1976165, 'mhevery', 123), ('everyjs.com', 1851714, 'mhevery', 6), ('todomvc', 1844251, 'tastejs', 26031), ('everyjs.com', 1819298, 'tomdale', 117), ('TestabilityBank', 1690044, 'mhevery', 3), ('TddCalculatorJava', 1688357, 'mhevery', 8), ('angular-demo-slides', 1413193, 'mhevery', 9), ('script.js', 1387097, 'ded', 2770), ('StoryNavigator', 1379292, 'paul-hammant', 25), ('angularjs.org', 1343653, 'angular', 265), ('angular-phonecat', 1170194, 'mhevery', 20), ('angular-phonecat', 1170151, 'IgorMinar', 4), ('mustache.js', 1036397, 'mhevery', 8), ('mustache', 1036381, 'mhevery', 2), ('UglifyJS', 839076, 'mishoo', 8150), ('ometa-js', 644874, 'alexwarth', 332), ('jasmine-jstd-adapter', 601966, 'mhevery', 39)]
#       name        id    owner  stars
# 0  angular  24195339  angular  54825
# [('angular', 24195339, 'angular', 54825), ('angular-dart-phonecat', 16302747, 'technohippy', 19), ('traceur-compiler', 9060347, 'google', 8034), ('testacular', 4409224, 'mhevery', 4), ('karma', 2560988, 'karma-runner', 11012), ('ng-slides', 2038280, 'mhevery', 7), ('ng-slides', 2038274, 'IgorMinar', 19), ('angular-node-socketio', 1976165, 'mhevery', 123), ('everyjs.com', 1851714, 'mhevery', 6), ('todomvc', 1844251, 'tastejs', 26031), ('everyjs.com', 1819298, 'tomdale', 117), ('TestabilityBank', 1690044, 'mhevery', 3), ('TddCalculatorJava', 1688357, 'mhevery', 8), ('angular-demo-slides', 1413193, 'mhevery', 9), ('script.js', 1387097, 'ded', 2770), ('StoryNavigator', 1379292, 'paul-hammant', 25), ('angularjs.org', 1343653, 'angular', 265), ('angular-phonecat', 1170194, 'mhevery', 20), ('angular-phonecat', 1170151, 'IgorMinar', 4), ('mustache.js', 1036397, 'mhevery', 8), ('mustache', 1036381, 'mhevery', 2), ('UglifyJS', 839076, 'mishoo', 8150), ('ometa-js', 644874, 'alexwarth', 332), ('jasmine-jstd-adapter', 601966, 'mhevery', 39), ('jasmine-node', 552007, 'mhevery', 1558)]
#       name        id    owner  stars
# 0  angular  24195339  angular  54825
# [('angular', 24195339, 'angular', 54825), ('angular-dart-phonecat', 16302747, 'technohippy', 19), ('traceur-compiler', 9060347, 'google', 8034), ('testacular', 4409224, 'mhevery', 4), ('karma', 2560988, 'karma-runner', 11012), ('ng-slides', 2038280, 'mhevery', 7), ('ng-slides', 2038274, 'IgorMinar', 19), ('angular-node-socketio', 1976165, 'mhevery', 123), ('everyjs.com', 1851714, 'mhevery', 6), ('todomvc', 1844251, 'tastejs', 26031), ('everyjs.com', 1819298, 'tomdale', 117), ('TestabilityBank', 1690044, 'mhevery', 3), ('TddCalculatorJava', 1688357, 'mhevery', 8), ('angular-demo-slides', 1413193, 'mhevery', 9), ('script.js', 1387097, 'ded', 2770), ('StoryNavigator', 1379292, 'paul-hammant', 25), ('angularjs.org', 1343653, 'angular', 265), ('angular-phonecat', 1170194, 'mhevery', 20), ('angular-phonecat', 1170151, 'IgorMinar', 4), ('mustache.js', 1036397, 'mhevery', 8), ('mustache', 1036381, 'mhevery', 2), ('UglifyJS', 839076, 'mishoo', 8150), ('ometa-js', 644874, 'alexwarth', 332), ('jasmine-jstd-adapter', 601966, 'mhevery', 39), ('jasmine-node', 552007, 'mhevery', 1558), ('angular.js', 465546, 'mhevery', 38)]
#       name        id    owner  stars
# 0  angular  24195339  angular  54825
# [('angular', 24195339, 'angular', 54825), ('angular-dart-phonecat', 16302747, 'technohippy', 19), ('traceur-compiler', 9060347, 'google', 8034), ('testacular', 4409224, 'mhevery', 4), ('karma', 2560988, 'karma-runner', 11012), ('ng-slides', 2038280, 'mhevery', 7), ('ng-slides', 2038274, 'IgorMinar', 19), ('angular-node-socketio', 1976165, 'mhevery', 123), ('everyjs.com', 1851714, 'mhevery', 6), ('todomvc', 1844251, 'tastejs', 26031), ('everyjs.com', 1819298, 'tomdale', 117), ('TestabilityBank', 1690044, 'mhevery', 3), ('TddCalculatorJava', 1688357, 'mhevery', 8), ('angular-demo-slides', 1413193, 'mhevery', 9), ('script.js', 1387097, 'ded', 2770), ('StoryNavigator', 1379292, 'paul-hammant', 25), ('angularjs.org', 1343653, 'angular', 265), ('angular-phonecat', 1170194, 'mhevery', 20), ('angular-phonecat', 1170151, 'IgorMinar', 4), ('mustache.js', 1036397, 'mhevery', 8), ('mustache', 1036381, 'mhevery', 2), ('UglifyJS', 839076, 'mishoo', 8150), ('ometa-js', 644874, 'alexwarth', 332), ('jasmine-jstd-adapter', 601966, 'mhevery', 39), ('jasmine-node', 552007, 'mhevery', 1558), ('angular.js', 465546, 'mhevery', 38), ('node-mongodb-native', 462292, 'mongodb', 8287)]
#       name        id    owner  stars
# 0  angular  24195339  angular  54825
# [('angular', 24195339, 'angular', 54825), ('angular-dart-phonecat', 16302747, 'technohippy', 19), ('traceur-compiler', 9060347, 'google', 8034), ('testacular', 4409224, 'mhevery', 4), ('karma', 2560988, 'karma-runner', 11012), ('ng-slides', 2038280, 'mhevery', 7), ('ng-slides', 2038274, 'IgorMinar', 19), ('angular-node-socketio', 1976165, 'mhevery', 123), ('everyjs.com', 1851714, 'mhevery', 6), ('todomvc', 1844251, 'tastejs', 26031), ('everyjs.com', 1819298, 'tomdale', 117), ('TestabilityBank', 1690044, 'mhevery', 3), ('TddCalculatorJava', 1688357, 'mhevery', 8), ('angular-demo-slides', 1413193, 'mhevery', 9), ('script.js', 1387097, 'ded', 2770), ('StoryNavigator', 1379292, 'paul-hammant', 25), ('angularjs.org', 1343653, 'angular', 265), ('angular-phonecat', 1170194, 'mhevery', 20), ('angular-phonecat', 1170151, 'IgorMinar', 4), ('mustache.js', 1036397, 'mhevery', 8), ('mustache', 1036381, 'mhevery', 2), ('UglifyJS', 839076, 'mishoo', 8150), ('ometa-js', 644874, 'alexwarth', 332), ('jasmine-jstd-adapter', 601966, 'mhevery', 39), ('jasmine-node', 552007, 'mhevery', 1558), ('angular.js', 465546, 'mhevery', 38), ('node-mongodb-native', 462292, 'mongodb', 8287), ('sammy', 458723, 'mhevery', 3)]
#       name        id    owner  stars
# 0  angular  24195339  angular  54825
# [('angular', 24195339, 'angular', 54825), ('angular-dart-phonecat', 16302747, 'technohippy', 19), ('traceur-compiler', 9060347, 'google', 8034), ('testacular', 4409224, 'mhevery', 4), ('karma', 2560988, 'karma-runner', 11012), ('ng-slides', 2038280, 'mhevery', 7), ('ng-slides', 2038274, 'IgorMinar', 19), ('angular-node-socketio', 1976165, 'mhevery', 123), ('everyjs.com', 1851714, 'mhevery', 6), ('todomvc', 1844251, 'tastejs', 26031), ('everyjs.com', 1819298, 'tomdale', 117), ('TestabilityBank', 1690044, 'mhevery', 3), ('TddCalculatorJava', 1688357, 'mhevery', 8), ('angular-demo-slides', 1413193, 'mhevery', 9), ('script.js', 1387097, 'ded', 2770), ('StoryNavigator', 1379292, 'paul-hammant', 25), ('angularjs.org', 1343653, 'angular', 265), ('angular-phonecat', 1170194, 'mhevery', 20), ('angular-phonecat', 1170151, 'IgorMinar', 4), ('mustache.js', 1036397, 'mhevery', 8), ('mustache', 1036381, 'mhevery', 2), ('UglifyJS', 839076, 'mishoo', 8150), ('ometa-js', 644874, 'alexwarth', 332), ('jasmine-jstd-adapter', 601966, 'mhevery', 39), ('jasmine-node', 552007, 'mhevery', 1558), ('angular.js', 465546, 'mhevery', 38), ('node-mongodb-native', 462292, 'mongodb', 8287), ('sammy', 458723, 'mhevery', 3), ('xsschannel', 427190, 'mhevery', 3)]
#       name        id    owner  stars
# 0  angular  24195339  angular  54825
# [('angular', 24195339, 'angular', 54825), ('angular-dart-phonecat', 16302747, 'technohippy', 19), ('traceur-compiler', 9060347, 'google', 8034), ('testacular', 4409224, 'mhevery', 4), ('karma', 2560988, 'karma-runner', 11012), ('ng-slides', 2038280, 'mhevery', 7), ('ng-slides', 2038274, 'IgorMinar', 19), ('angular-node-socketio', 1976165, 'mhevery', 123), ('everyjs.com', 1851714, 'mhevery', 6), ('todomvc', 1844251, 'tastejs', 26031), ('everyjs.com', 1819298, 'tomdale', 117), ('TestabilityBank', 1690044, 'mhevery', 3), ('TddCalculatorJava', 1688357, 'mhevery', 8), ('angular-demo-slides', 1413193, 'mhevery', 9), ('script.js', 1387097, 'ded', 2770), ('StoryNavigator', 1379292, 'paul-hammant', 25), ('angularjs.org', 1343653, 'angular', 265), ('angular-phonecat', 1170194, 'mhevery', 20), ('angular-phonecat', 1170151, 'IgorMinar', 4), ('mustache.js', 1036397, 'mhevery', 8), ('mustache', 1036381, 'mhevery', 2), ('UglifyJS', 839076, 'mishoo', 8150), ('ometa-js', 644874, 'alexwarth', 332), ('jasmine-jstd-adapter', 601966, 'mhevery', 39), ('jasmine-node', 552007, 'mhevery', 1558), ('angular.js', 465546, 'mhevery', 38), ('node-mongodb-native', 462292, 'mongodb', 8287), ('sammy', 458723, 'mhevery', 3), ('xsschannel', 427190, 'mhevery', 3), ('fin', 425399, 'marcuswestin', 87)]
#       name        id    owner  stars
# 0  angular  24195339  angular  54825
#                           name         id         owner  stars
# 0                 var-exporter  146569764       symfony   1000
# 0                 var-exporter  146569764       symfony   1000
# 1            service-contracts  188791042       symfony    891
# 0                 var-exporter  146569764       symfony   1000
# 1            service-contracts  188791042       symfony    891
# 2               polyfill-php73  131031925       symfony   1025
# 0                 var-exporter  146569764       symfony   1000
# 1            service-contracts  188791042       symfony    891
# 2               polyfill-php73  131031925       symfony   1025
# 3            polyfill-intl-idn  151089715       symfony   1666
# 0                 var-exporter  146569764       symfony   1000
# 1            service-contracts  188791042       symfony    891
# 2               polyfill-php73  131031925       symfony   1025
# 3            polyfill-intl-idn  151089715       symfony   1666
# 4                         mime  166176986       symfony   1074
# 0                 var-exporter  146569764       symfony   1000
# 1            service-contracts  188791042       symfony    891
# 2               polyfill-php73  131031925       symfony   1025
# 3            polyfill-intl-idn  151089715       symfony   1666
# 4                         mime  166176986       symfony   1074
# 5   event-dispatcher-contracts  188787832       symfony   1215
# 0                 var-exporter  146569764       symfony   1000
# 1            service-contracts  188791042       symfony    891
# 2               polyfill-php73  131031925       symfony   1025
# 3            polyfill-intl-idn  151089715       symfony   1666
# 4                         mime  166176986       symfony   1074
# 5   event-dispatcher-contracts  188787832       symfony   1215
# 6               error-renderer  194141419       symfony     59
# 0                 var-exporter  146569764       symfony   1000
# 1            service-contracts  188791042       symfony    891
# ..                         ...        ...           ...    ...
# 0                      angular   24195339       angular  54825
# 1        angular-dart-phonecat   16302747   technohippy     19
# 2             traceur-compiler    9060347        google   8034
# 3                   testacular    4409224       mhevery      4
# 4                        karma    2560988  karma-runner  11012
# 5                    ng-slides    2038280       mhevery      7
# 6                    ng-slides    2038274     IgorMinar     19
# 7        angular-node-socketio    1976165       mhevery    123
# 8                  everyjs.com    1851714       mhevery      6
# 9                      todomvc    1844251       tastejs  26031
# 10                 everyjs.com    1819298       tomdale    117
# 11             TestabilityBank    1690044       mhevery      3
# 12           TddCalculatorJava    1688357       mhevery      8
# 13         angular-demo-slides    1413193       mhevery      9
# 14                   script.js    1387097           ded   2770
# 15              StoryNavigator    1379292  paul-hammant     25
# 16               angularjs.org    1343653       angular    265
# 17            angular-phonecat    1170194       mhevery     20
# 18            angular-phonecat    1170151     IgorMinar      4
# 19                 mustache.js    1036397       mhevery      8
# 20                    mustache    1036381       mhevery      2
# 21                    UglifyJS     839076        mishoo   8150
# 22                    ometa-js     644874     alexwarth    332
# 23        jasmine-jstd-adapter     601966       mhevery     39
# 24                jasmine-node     552007       mhevery   1558
# 25                  angular.js     465546       mhevery     38
# 26         node-mongodb-native     462292       mongodb   8287
# 27                       sammy     458723       mhevery      3
# 28                  xsschannel     427190       mhevery      3
# 29                         fin     425399  marcuswestin     87
#
# [25311 rows x 4 columns]

# %%
r.get("https://api.github.com/users/{}/starred".format('Magobol'),headers={"Authorization":"15d2ae65a434e6375573c0c1f835c4d4d5008a2205329482273486611b4797ff"}).content
# Out:
# b'{"message":"API rate limit exceeded for 137.194.120.205. (But here\'s the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)","documentation_url":"https://developer.github.com/v3/#rate-limiting"}'

# %%
final.groupby("owner").mean().sort_values("stars",ascending=False)
# Out:
#                            id         stars
# owner
# electron         9.384267e+06  77777.000000
# donnemartin      8.322244e+07  75228.000000
# nodejs           2.719378e+07  65102.000000
# golang           2.309696e+07  64877.000000
# public-apis      5.434680e+07  63957.000000
# moby             7.691631e+06  55215.000000
# elastic          5.077750e+05  44920.000000
# resume           1.334369e+06  42386.000000
# meteor           3.214406e+06  41373.000000
# prettier         7.510412e+07  34030.000000
# gothinkster      5.263184e+07  32864.000000
# serverless       3.430270e+07  32455.000000
# GoogleChrome     9.541493e+07  32181.193548
# grafana          1.511182e+07  31559.000000
# discourse        7.569578e+06  29256.000000
# fatedier         4.837895e+07  28691.000000
# immutable-js     2.141320e+07  28541.000000
# minimaxir        5.409580e+07  28087.500000
# home-assistant   1.288899e+07  27614.000000
# koajs            1.155154e+07  27591.000000
# zenorocha        4.275101e+07  27238.000000
# jlevy            4.338490e+07  26529.333333
# storybookjs      7.219421e+07  25982.902439
# tastejs          1.844251e+06  25917.000000
# angular          1.507657e+07  25392.713333
# sveltejs         7.429332e+07  25170.000000
# Blankj           6.455814e+07  25100.000000
# caddyserver      2.920762e+07  24548.000000
# kelseyhightower  8.788059e+07  24454.260870
# quilljs          5.239185e+06  24329.000000
# ...                       ...           ...
# paulmillr        1.959209e+08      3.000000
# alkalinecoffee   7.917073e+07      3.000000
# meixuesong       2.091869e+08      3.000000
# 6by9             1.301843e+08      3.000000
# umijs            2.163144e+08      3.000000
# sbirss           1.759202e+08      3.000000
# antvis           2.143708e+08      3.000000
# sdhand           1.711784e+08      3.000000
# umber            1.366262e+08      3.000000
# Brooksrh         1.635937e+08      3.000000
# tangtaoshadow    2.001096e+08      3.000000
# simonratner      1.004513e+08      3.000000
# DualBrain        1.795170e+08      3.000000
# aliyun           1.117773e+08      3.000000
# plataformatec    4.652304e+06      3.000000
# kamn             6.816561e+07      3.000000
# rodrigoflores    3.605795e+06      3.000000
# stokesbga        8.468319e+07      2.000000
# tchak            2.053943e+08      2.000000
# tatey            2.408759e+07      2.000000
# srl295           2.153286e+08      2.000000
# cloudfoundry     1.848176e+08      1.909091
# rachaelshaw      8.912517e+07      1.000000
# piternet         1.273077e+08      1.000000
# mtnwrw           1.596411e+08      1.000000
# CMcGoldrick      1.866862e+08      1.000000
# rafaelfranca     4.597929e+06      1.000000
# Avimesa          1.570484e+08      1.000000
# sheelc           1.416478e+07      1.000000
# guyellis         2.057104e+08      1.000000
#
# [1199 rows x 2 columns]

# %%
len(users)
# Out:
# 256
